# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("kmeans_large_dataset.xls")

# %%
df
# Out:
#       feature_1  feature_2  true_cluster
# 0     -3.060786   7.718475             0
# 1     -8.654036  -9.555722             2
# 2      5.376404   2.423717             1
# 3     -7.883233  -9.119847             2
# 4     -6.038120  -6.012425             2
# ...         ...        ...           ...
# 9995   2.444261   2.712330             1
# 9996  -5.156599  -6.538629             2
# 9997  -7.431317  -7.287016             2
# 9998  -2.139836   6.962084             0
# 9999   2.475378   2.370935             1
#
# [10000 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   feature_1     10000 non-null  float64
#  1   feature_2     10000 non-null  float64
#  2   true_cluster  10000 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 234.5 KB

# %%
plt.scatter(df["feature_1"],df["feature_2"])
plt.show()

# %%
Kmeans = KMeans(n_clusters = 8 , random_state = 42)
label = Kmeans.fit_predict(df)

# %%
plt.scatter(df["feature_1"], df["feature_2"], c= label)
plt.scatter(
    Kmeans.cluster_centers_[:,0],
    Kmeans.cluster_centers_[:,1],
    marker = 'X',
    s = 200
)
plt.title("K-Means on our Dataset")
plt.show()
